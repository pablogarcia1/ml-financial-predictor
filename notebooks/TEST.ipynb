# %%
import pandas as pd  
df = pd.read_parquet("../data/processed/SPY.parquet")
print(df.index[-3:])
# Out:
# DatetimeIndex(['2026-03-12', '2026-03-13', '2026-03-16'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
df = pd.read_parquet("../data/raw/SPY.parquet")
print(df.index[-3:])
# Out:
# DatetimeIndex(['2026-03-26', '2026-03-27', '2026-03-30'], dtype='datetime64[ns]', name='Date', freq=None)
